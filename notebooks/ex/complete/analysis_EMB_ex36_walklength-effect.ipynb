# %% [markdown]
# # Examining walk length effect

# %% [markdown]
# ## <font color="red"> Experiment description **Not updated from ex35!** </font>
# ### Narrative set-up
# Recent results suggest that our current methodology is unable to reproduce the prior results utilizing only degree information (ex33v2.1, see [Reference Figure (1)](#ref-fig-1)). However, this does not rely on embedding information at all and hence, under logistic regression, should be able to reproduce prior "DC"-classifier results nearly exactly, up to very minor fluctuations due to random observations. Hence, we find ourselves needing to re-examine the fundamentals of our current workflow's reconstruction.
#
# This experiment is a follow-up to EMB_ex34 which established the inconsistency of network size in current experiments and prior work is responsible for the observed performance discrepancies. See [Reference Figure (2)](#ref-fig-2) for an annotated figure illustrating this phenomena.
#
# ### Goal
# The main goal of this experiment is to run an "all features" version of both our current LogReg-classifier and our previous "DC" classifier on the same LFR benchmarks to see if an exactly equivalent experimental setting is able to produce comparable results.
#
# This is motivated by the results of EMB_ex34 suggesting that size discrepancies, originally enacted for speed with the slow embedding process, is the primary contributor to current performance discrepancies.

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Set-up

# %% [markdown]
# ## Package management

# %%
# --- Standard library ---
import sys
import pickle
from enum import Enum
import random

# --- Scientific computing ---
import numpy as np
from sklearn.metrics import accuracy_score, roc_auc_score

# --- Network science ---
from cdlib import algorithms
import networkx as nx
from node2vec import Node2Vec

# --- Data handling and visualization ---
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator
# %matplotlib inline

# --- Project source code ---
sys.path.append("../../")
from src.data.preprocessing import duplex_network  # handle overlap, inconsistent node sets
from src.data.benchmarks import generate_multiplex_configuration, lfr_multiplex  # benchmark samplers
from src.sampling.random import partial_information  # PFI observation
from src.classifiers.features import *  # degree feature calculations, label wrapper
from src.classifiers.logreg import *  # wrappers for scikit-learn logistic regression model functions

# %% [markdown]
# ## Global config

# %%
# * Pathing aliases
_ROOT = "../../"
_DATA = _ROOT + "data/input/"
_DFS = _ROOT + "results/dataframes/"
_FIGS = _ROOT + "results/plots/"

# %%
# * Plotting parameters
custom_plot_settings = {
    # Figure config
    "figure.figsize": (8,6),
    "figure.frameon": True,
    "figure.autolayout": True,
    "axes.titlesize": 16,
    # Axes config
    "xtick.minor.size": 2,
    # Save-to-disk config
    "savefig.facecolor": "white",
    "savefig.transparent": False
}
mpl.rcParams.update(custom_plot_settings)

# * Plotting aliases
colors_ = ["black", "red", "blue", "green", "purple"]
markers_ = ["o", "s", "+", "^", "v"]
viridis_ = mpl.colormaps['viridis']

# %% [markdown]
# ---

# %% [markdown]
# # Experiment

# %% [markdown]
# ## Function set-up

# %%
def renormalize_embedding_per_component (G, n2v_emb):
    n2v_emb_rescaled = {}
    for n in G:
        n2v_emb_rescaled[n] = n2v_emb.wv[str(n)]

    nr_comp = 0
    components = nx.connected_components(G)
    for c in components:
        nr_comp += 1
        list_of_nodes = []
        norm = 0.0
        for n in c:
            list_of_nodes.append(n2v_emb_rescaled[n])
        cm = np.add.reduce(list_of_nodes) / float(len(list_of_nodes))
        for n in c:
            n2v_emb_rescaled[n] = n2v_emb_rescaled[n] - cm
            norm += np.linalg.norm(n2v_emb_rescaled[n])
        if norm > 0.0:
            for n in c:
                n2v_emb_rescaled[n] = n2v_emb_rescaled[n] / norm

    return n2v_emb_rescaled

# %% [markdown]
# ## Data set-up

# %% [markdown]
# ### Specify parameters

# %%
_DATA_DICT = {
    "N": "number of nodes (in shared node set)",
    "GAMMA": "degree exponent of power-law degree distribution (from sampled distribution, finite sampling effects may yield different exponent if re-fit)",
    "MU": "mixing parameter for LFR model. Smaller MU implies (and is implied by) stronger modular structure.",
    "KMIN": "minimum degree (in either layer)",
    "KMAX": "maximum degree (in either layer)",
    "AVG_K": "average degree (in both layers)",
    "T1": "equivalent to GAMMA for LFR models",
    "T2": "community size power-law distribution exponent",
    "PROB": "relabeling probability. Controls correlation, with 0->1 = correlated->uncorrelated",
    "SIGN": "degree sequence sorting. Couples with PROB to produce anti/directly correlated degree sequences. -1 => anticorrelated, 1 => correlated"
}

# %%
class NetworkParams(Enum):
    # Shared params
    N = 1_000
    PROB = 1.0
    GAMMA = 2.1
    KMAX = np.sqrt(1_000)
    # Configuration model params
    KMIN = 3
    SIGN = 1
    # LFR params
    AVG_K = 6.0
    T2 = 1.0
    MU = 0.1
    MIN_COMMUNITY = 1 # ignored

# %%
class ExperimentParams(Enum):
    THETAS = np.linspace(0.05, 0.95, 10, endpoint=True)

# %%
LOGREG = {"fit_intercept": True, "solver": "newton-cholesky", "penalty": None}

# %% [markdown]
# ### Sample duplex

# %%
duplex, _, _, _ = lfr_multiplex(
    int(NetworkParams.N.value),  # number of nodes
    NetworkParams.GAMMA.value,  # degree distribution exponent
    NetworkParams.T2.value,  # community size distribution exponent
    NetworkParams.MU.value,  # community mixing parameter
    NetworkParams.AVG_K.value,  # average degree
    NetworkParams.KMAX.value,  # maximum degree
    NetworkParams.MIN_COMMUNITY.value,  # minimum community size (ignored)
    NetworkParams.PROB.value,  # degree sequence correlation
)
# Out:
# setting... -N 1000
# setting... -k 6.0
# setting... -maxk 31.622776601683793
# setting... -t1 2.1
# setting... -t2 1.0
# setting... -mu 0.1
#
# **************************************************************
# number of nodes:	1000
# average degree:	6
# maximum degree:	32
# exponent for the degree distribution:	2.1
# exponent for the community size distribution:	1
# mixing parameter:	0.1
# number of overlapping nodes:	0
# number of memberships of the overlapping nodes:	0
# **************************************************************
#
# -----------------------------------------------------------
# community size range automatically set equal to [3 , 32]
# it took too long to decide the memberships; I will try to change the community sizes
# new community sizes
# 19 10 11 6 14 29 28 4 8 4 15 28 4 27 28 5 6 30 15 6 24 12 7 4 19 21 3 21 17 3 13 7 25 22 9 3 28 9 7 7 4 5 21 12 16 3 4 10 17 29 15 26 11 7 14 5 5 14 4 5 10 3 9 5 19 3 3 5 4 13 9 15 13 7 7 30 6 11 6 3 7 27
#
# it took too long to decide the memberships; I will try to change the community sizes
# new community sizes
# 10 11 6 14 29 28 4 8 4 15 28 4 27 28 5 6 30 15 6 24 12 7 4 19 21 3 21 17 3 13 7 25 22 9 3 28 9 7 7 4 5 21 12 16 3 4 10 17 29 15 26 11 7 14 5 5 14 4 5 10 3 9 5 19 3 3 5 19 13 9 15 13 7 7 30 6 11 6 7 7 27
#
# it took too long to decide the memberships; I will try to change the community sizes
# new community sizes
# 11 6 14 29 28 4 8 4 15 28 4 27 28 5 6 30 15 6 24 12 7 4 19 21 3 21 17 3 13 7 25 22 9 3 28 9 7 7 4 5 21 12 16 3 4 10 17 29 15 26 11 7 14 5 5 14 10 5 10 3 9 5 19 3 7 5 19 13 9 15 13 7 7 30 6 11 6 7 7 27
#
# it took too long to decide the memberships; I will try to change the community sizes
# new community sizes
# 6 14 29 28 4 8 4 15 28 4 27 28 5 6 30 15 6 24 12 7 4 19 21 3 21 17 3 13 7 25 22 9 3 28 9 7 7 4 5 21 12 16 3 11 10 17 29 15 26 11 7 14 5 5 14 10 5 10 3 9 5 19 7 7 5 19 13 9 15 13 7 7 30 6 11 6 7 7 27
#
# it took too long to decide the memberships; I will try to change the community sizes
# new community sizes
# 14 29 28 4 8 4 15 28 4 27 28 5 6 30 15 6 24 12 7 4 19 21 3 21 17 3 13 7 25 22 9 3 28 9 7 7 6 5 21 12 16 3 11 10 17 29 15 26 11 7 14 5 5 14 10 5 10 7 9 5 19 7 7 5 19 13 9 15 13 7 7 30 6 11 6 7 7 27
#
# it took too long to decide the memberships; I will try to change the community sizes
# new community sizes
# 29 28 4 8 4 15 28 4 27 28 5 6 30 15 6 24 12 7 14 19 21 3 21 17 3 13 7 25 22 9 3 28 9 7 7 6 5 21 12 16 7 11 10 17 29 15 26 11 7 14 5 5 14 10 5 10 7 9 5 19 7 7 5 19 13 9 15 13 7 7 30 6 11 6 7 7 27
#
# building communities...
# connecting communities...
# recording network...
#
#
# ---------------------------------------------------------------------------
# network of 1000 vertices and 3349 edges;	 average degree = 6.698
#
# average mixing parameter: 0.0993991 +/- 0.114072
# p_in: 0.531527	p_out: 0.00058921
# Segmentation fault

# %%
G, H = duplex_network(duplex, 1, 2, verbose=True)
# Out:
# Number of common edges removed: 13
# Number of inactive nodes removed from layer 1: 0
# Number of inactive nodes removed from layer 2: 0
# Size of active node set union from layers 1 and 2: 2000

# %% [markdown]
# ### Compute remnants

# %%
remnants = dict()  # theta -> [remnants infomation] mapping
for theta in ExperimentParams.THETAS.value:
    remnant_G, remnant_H, test_edges, train_edges = partial_information(G, H, theta)
    record = {
        "remnants": (remnant_G, remnant_H),
        "observed_edges": train_edges,
        "unobserved_edges": test_edges
    }
    remnants[theta] = record

# %% [markdown]
# ## Feature calculation

# %%
features_labels_by_WL = dict()  # walk_length -> (features, labels)

# %%
for walk_length in np.linspace(5, 100, num=10, endpoint=True):
    features = dict()  # theta -> [train features, test features]
    labels = dict()  # theta -> [train labels, test labels]
    for theta, record in remnants.items():
        # --- Degree feature ---
        # Partially compute degree likelihood feature
        src_degrees_train, tgt_degrees_train = get_degrees(record["remnants"], list(record["observed_edges"].keys()))
        src_degrees_test, tgt_degrees_test = get_degrees(record["remnants"], list(record["unobserved_edges"].keys()))

        # Complete degree likelihood feature calculations
        feature_degrees_train = get_configuration_probabilities_feature(src_degrees_train, tgt_degrees_train)
        feature_degrees_test = get_configuration_probabilities_feature(src_degrees_test, tgt_degrees_test)

        # --- Embedding feature ---
        # & Embed remnants
        node2vec1 = Node2Vec(record["remnants"][0], dimensions=128, walk_length=walk_length, num_walks=10, workers=6)
        node2vec2 = Node2Vec(record["remnants"][1], dimensions=128, walk_length=walk_length, num_walks=10, workers=6)

        model1 = node2vec1.fit(window=10, min_count=1, batch_words=4)
        model2 = node2vec2.fit(window=10, min_count=1, batch_words=4)

        # & Align centers
        embeddings_G = renormalize_embedding_per_component(record["remnants"][0], model1)
        embeddings_H = renormalize_embedding_per_component(record["remnants"][1], model2)

        distances_G_train, distances_H_train = \
            get_distances((embeddings_G, embeddings_H), list(record["observed_edges"].keys()))
        distances_G_test, distances_H_test = \
            get_distances((embeddings_G, embeddings_H), list(record["unobserved_edges"].keys()))

        feature_distances_train = get_configuration_distances_feature(distances_G_train, distances_H_train, zde_penalty=0.1)
        feature_distances_test = get_configuration_distances_feature(distances_G_test, distances_H_test, zde_penalty=0.1)

        normalizer = max(
            np.abs(min(feature_distances_train)),
            np.abs(max(feature_distances_train)),
        )
        feature_distances_train = [x / normalizer for x in feature_distances_train]

        normalizer = max(
            np.abs(min(feature_distances_test)),
            np.abs(max(feature_distances_test)),
        )
        feature_distances_test = [x / normalizer for x in feature_distances_test]

        # --- Cleaning up features ---
        feature_matrix_train, feature_matrix_test = \
            format_feature_matrix(
                {"emb", "imb", "deg"},
                len(record["observed_edges"]), len(record["unobserved_edges"]),
                feature_distances_train, feature_distances_test,
                feature_degrees_train, feature_degrees_test
            )

        # --- Labels ---
        labels_train, labels_test = get_labels(record["observed_edges"], record["unobserved_edges"])

        # Save to feature and label mappings
        features[theta] = (feature_matrix_train, feature_matrix_test)
        labels[theta] = (labels_train, labels_test)

    # Group by walk_length
    features_labels_by_WL[walk_length] = (features, labels)
# Out:
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2012.31it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  6.34it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  7.61it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  7.63it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  7.27it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  7.15it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  9.04it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2034.32it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  8.33it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  8.61it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  8.46it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  8.33it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  7.20it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  9.38it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2313.28it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  8.97it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  8.88it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  9.47it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  9.27it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  9.07it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  9.55it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2405.09it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  9.03it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  8.96it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  8.89it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  8.52it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  9.41it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  9.46it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2564.70it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  8.51it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  9.09it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  8.82it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  8.09it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  7.77it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  9.29it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2403.53it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  9.67it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  8.42it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  8.78it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  9.16it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  9.39it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  9.39it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2573.25it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  9.13it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  9.06it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  8.63it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  8.55it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  8.78it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  9.46it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2758.43it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  9.43it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  9.11it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  8.66it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  8.79it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  8.73it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  9.34it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2952.10it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  9.12it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  9.15it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  9.16it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  8.50it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  9.29it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  9.34it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2992.12it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  9.68it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  7.95it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  8.19it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  8.96it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  9.12it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  9.03it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 3200.11it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  9.37it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  9.18it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  9.45it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  8.90it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  8.85it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  9.40it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 3463.58it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  9.13it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  8.98it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  9.17it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  9.20it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  9.26it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  9.64it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 3653.34it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  9.54it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  9.17it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  8.98it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  8.69it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  8.11it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  9.71it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 3610.85it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  8.99it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  8.60it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  7.81it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  8.81it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  9.06it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  9.49it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 4025.51it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  8.09it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  8.14it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  9.41it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  9.21it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  8.22it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  9.31it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 3897.99it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  9.15it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  8.86it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  9.17it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  7.86it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  8.53it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  9.59it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 4209.57it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  9.41it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  8.75it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  8.36it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  8.19it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  8.19it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  9.49it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 4271.44it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  9.32it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  8.67it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  8.71it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  8.19it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  8.24it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  9.17it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 4583.61it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  8.99it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  7.50it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  7.91it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  9.57it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  8.77it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  9.35it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 4736.58it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  9.10it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  8.08it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  8.29it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  8.48it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  8.72it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  9.02it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2030.17it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  2.30it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  2.12it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  2.09it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  2.08it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  2.34it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  2.17it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2039.38it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  2.21it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  2.04it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  2.17it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  2.16it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  2.27it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  2.17it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2241.54it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  2.15it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:01<00:00,  2.00it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  1.91it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  2.16it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  2.12it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  2.17it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2361.92it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  2.38it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  2.10it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  2.10it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  1.93it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  2.18it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  2.25it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2443.86it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  2.37it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  2.14it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  2.20it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  2.19it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  2.27it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  2.21it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2459.96it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  2.20it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  2.10it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  2.07it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  2.18it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  2.17it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  2.23it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2651.07it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  2.32it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  2.18it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  2.18it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  2.16it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  2.06it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  2.20it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2709.73it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  2.38it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  2.24it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  2.18it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  2.32it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  2.15it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  2.25it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2920.77it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  2.27it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  2.07it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  1.95it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  2.07it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  2.08it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  2.17it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2916.12it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  2.23it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  2.17it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  2.19it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  2.49it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  2.17it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  2.24it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 3538.23it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  2.28it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  1.90it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  2.09it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  2.24it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  2.20it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  2.11it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 3195.11it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  2.33it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  2.05it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  2.06it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  2.23it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  2.20it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  2.20it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 3832.60it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  2.40it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  2.15it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  2.15it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  2.03it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  2.18it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  2.21it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 3489.97it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  2.26it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  1.96it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  2.36it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  2.16it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  2.22it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  2.32it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 3903.56it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  2.24it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  2.15it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  2.21it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  2.14it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  2.25it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  2.14it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 3844.72it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  2.25it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  2.13it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  2.18it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  1.98it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  2.13it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  2.30it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 4609.08it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  2.17it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  2.16it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  2.25it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  2.23it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  2.33it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  2.25it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2536.77it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  2.19it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  1.95it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  2.15it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  2.19it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  2.13it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  2.21it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 4700.08it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  2.17it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  2.16it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  2.10it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  2.06it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  2.17it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  2.28it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 4640.69it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  2.28it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00,  2.32it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00,  2.25it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  2.11it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00,  2.39it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00,  2.31it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2075.26it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  1.30it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  1.19it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:01<00:00,  1.26it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:01<00:00,  1.26it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:01<00:00,  1.27it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2054.65it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  1.11it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:01<00:00,  1.17it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:01<00:00,  1.20it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  1.10it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:01<00:00,  1.20it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:01<00:00,  1.28it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2208.68it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  1.15it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:01<00:00,  1.16it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  1.14it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:01<00:00,  1.21it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:01<00:00,  1.24it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:01<00:00,  1.22it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2195.25it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  1.16it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:01<00:00,  1.24it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:01<00:00,  1.23it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  1.12it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:01<00:00,  1.23it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:01<00:00,  1.24it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2370.93it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  1.23it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:01<00:00,  1.29it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  1.17it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:01<00:00,  1.27it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:01<00:00,  1.21it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:01<00:00,  1.20it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2529.73it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  1.08it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:01<00:00,  1.24it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:01<00:00,  1.28it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  1.11it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:01<00:00,  1.20it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:01<00:00,  1.26it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2535.43it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  1.14it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  1.11it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:01<00:00,  1.15it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:01<00:00,  1.16it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:01<00:00,  1.24it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:01<00:00,  1.18it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2619.98it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  1.15it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:01<00:00,  1.26it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:01<00:00,  1.24it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:01<00:00,  1.24it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:01<00:00,  1.27it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2746.25it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  1.09it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  1.16it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:01<00:00,  1.19it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:01<00:00,  1.21it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:01<00:00,  1.17it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:01<00:00,  1.20it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2818.54it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  1.09it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  1.10it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:01<00:00,  1.15it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:01<00:00,  1.19it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:01<00:00,  1.18it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:01<00:00,  1.16it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 3296.54it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  1.09it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  1.12it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:01<00:00,  1.16it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:01<00:00,  1.17it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:01<00:00,  1.14it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:01<00:00,  1.18it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 3184.04it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  1.18it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  1.17it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:01<00:00,  1.25it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:01<00:00,  1.22it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:01<00:00,  1.26it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:01<00:00,  1.21it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 3344.23it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  1.08it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  1.04it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:01<00:00,  1.13it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:01<00:00,  1.18it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:01<00:00,  1.22it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:01<00:00,  1.16it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 3433.64it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  1.12it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  1.20it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:01<00:00,  1.13it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:01<00:00,  1.19it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:01<00:00,  1.16it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:01<00:00,  1.21it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 3767.95it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  1.10it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  1.08it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:01<00:00,  1.22it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:01<00:00,  1.21it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:01<00:00,  1.17it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:01<00:00,  1.21it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 3629.94it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  1.05it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  1.07it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:01<00:00,  1.16it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:01<00:00,  1.17it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:01<00:00,  1.21it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:01<00:00,  1.19it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 3983.95it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  1.16it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  1.10it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:01<00:00,  1.24it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:01<00:00,  1.25it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:01<00:00,  1.24it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:01<00:00,  1.24it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 4257.04it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  1.06it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  1.15it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:01<00:00,  1.22it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:01<00:00,  1.15it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:01<00:00,  1.14it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:01<00:00,  1.16it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 4898.08it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  1.14it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  1.18it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:01<00:00,  1.17it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:01<00:00,  1.24it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:01<00:00,  1.25it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:01<00:00,  1.23it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 4708.23it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:00<00:00,  1.26it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:00<00:00,  1.09it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:01<00:00,  1.20it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:01<00:00,  1.26it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:01<00:00,  1.29it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:01<00:00,  1.27it/s]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2075.07it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:01<00:00,  1.18s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:01<00:00,  1.19s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:02<00:00,  1.10s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:02<00:00,  1.19s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:02<00:00,  1.14s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:02<00:00,  1.13s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 1916.90it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:01<00:00,  1.27s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:01<00:00,  1.27s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:02<00:00,  1.21s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:02<00:00,  1.19s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:02<00:00,  1.14s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:02<00:00,  1.12s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2140.59it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:01<00:00,  1.23s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:01<00:00,  1.18s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:02<00:00,  1.19s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:02<00:00,  1.17s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:02<00:00,  1.21s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:02<00:00,  1.14s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2331.12it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:01<00:00,  1.34s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:01<00:00,  1.30s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:02<00:00,  1.20s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:02<00:00,  1.19s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:02<00:00,  1.18s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:02<00:00,  1.15s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2308.63it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:01<00:00,  1.20s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:01<00:00,  1.27s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:02<00:00,  1.16s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:02<00:00,  1.18s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:02<00:00,  1.19s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:02<00:00,  1.18s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2169.76it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:01<00:00,  1.26s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:01<00:00,  1.26s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:02<00:00,  1.16s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:02<00:00,  1.19s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:02<00:00,  1.17s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:02<00:00,  1.16s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2448.85it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:01<00:00,  1.27s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:01<00:00,  1.19s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:02<00:00,  1.11s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:02<00:00,  1.17s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:02<00:00,  1.17s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:02<00:00,  1.12s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2452.80it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:01<00:00,  1.22s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:01<00:00,  1.18s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:02<00:00,  1.19s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:02<00:00,  1.12s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:02<00:00,  1.12s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:02<00:00,  1.15s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 3021.06it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:01<00:00,  1.19s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:01<00:00,  1.22s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:02<00:00,  1.18s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:02<00:00,  1.21s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:02<00:00,  1.18s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:02<00:00,  1.13s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2681.11it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:01<00:00,  1.39s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:01<00:00,  1.36s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:02<00:00,  1.28s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:02<00:00,  1.30s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:02<00:00,  1.27s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:02<00:00,  1.25s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 3028.14it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:01<00:00,  1.29s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:01<00:00,  1.18s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:02<00:00,  1.17s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:02<00:00,  1.13s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:02<00:00,  1.12s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:02<00:00,  1.15s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 1690.61it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:01<00:00,  1.18s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:01<00:00,  1.27s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:02<00:00,  1.18s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:02<00:00,  1.19s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:02<00:00,  1.17s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:02<00:00,  1.11s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 3141.88it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:01<00:00,  1.23s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:01<00:00,  1.17s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:02<00:00,  1.15s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:02<00:00,  1.15s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:02<00:00,  1.15s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:02<00:00,  1.14s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 3249.30it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:01<00:00,  1.27s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:01<00:00,  1.25s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:02<00:00,  1.17s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:02<00:00,  1.12s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:02<00:00,  1.11s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:02<00:00,  1.14s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 4096.65it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:01<00:00,  1.19s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:01<00:00,  1.22s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:02<00:00,  1.13s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:02<00:00,  1.13s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:02<00:00,  1.14s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:02<00:00,  1.13s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 3634.65it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:01<00:00,  1.20s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:01<00:00,  1.17s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:02<00:00,  1.10s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:02<00:00,  1.15s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:02<00:00,  1.11s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:02<00:00,  1.12s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 4036.34it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:01<00:00,  1.24s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:01<00:00,  1.25s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:02<00:00,  1.17s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:02<00:00,  1.15s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:02<00:00,  1.12s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:02<00:00,  1.15s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 3969.95it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:01<00:00,  1.26s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:01<00:00,  1.19s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:02<00:00,  1.14s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:02<00:00,  1.14s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:02<00:00,  1.10s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:02<00:00,  1.17s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 4408.02it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:01<00:00,  1.13s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:01<00:00,  1.18s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:02<00:00,  1.07s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:02<00:00,  1.13s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:02<00:00,  1.12s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:02<00:00,  1.10s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 4148.71it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:01<00:00,  1.20s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:01<00:00,  1.18s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:02<00:00,  1.06s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:02<00:00,  1.10s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:02<00:00,  1.08s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:02<00:00,  1.06s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 1980.44it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:01<00:00,  1.65s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:01<00:00,  1.67s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:03<00:00,  1.58s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:03<00:00,  1.53s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:03<00:00,  1.52s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:03<00:00,  1.56s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2058.88it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:01<00:00,  1.54s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:01<00:00,  1.68s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:02<00:00,  1.48s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:03<00:00,  1.53s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:03<00:00,  1.54s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:02<00:00,  1.49s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2082.47it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:01<00:00,  1.65s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:01<00:00,  1.66s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:03<00:00,  1.52s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:03<00:00,  1.60s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:03<00:00,  1.52s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:03<00:00,  1.54s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2120.17it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:01<00:00,  1.53s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:01<00:00,  1.63s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:03<00:00,  1.55s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:03<00:00,  1.54s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:03<00:00,  1.52s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:03<00:00,  1.56s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2301.08it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:01<00:00,  1.56s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:01<00:00,  1.68s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:02<00:00,  1.42s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:03<00:00,  1.51s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:02<00:00,  1.48s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:02<00:00,  1.49s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2293.26it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:01<00:00,  1.49s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:01<00:00,  1.52s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:02<00:00,  1.46s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:02<00:00,  1.47s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:02<00:00,  1.43s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:03<00:00,  1.50s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2294.87it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:01<00:00,  1.62s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:01<00:00,  1.66s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:03<00:00,  1.53s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:03<00:00,  1.53s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:02<00:00,  1.50s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:02<00:00,  1.48s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2463.22it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:01<00:00,  1.52s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:01<00:00,  1.71s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:02<00:00,  1.50s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:03<00:00,  1.54s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:03<00:00,  1.53s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:03<00:00,  1.52s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2663.11it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:01<00:00,  1.53s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:01<00:00,  1.57s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:02<00:00,  1.44s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:03<00:00,  1.53s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:02<00:00,  1.47s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:02<00:00,  1.47s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2768.45it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:01<00:00,  1.59s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:01<00:00,  1.64s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:03<00:00,  1.51s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:03<00:00,  1.51s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:03<00:00,  1.51s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:03<00:00,  1.52s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2942.89it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:01<00:00,  1.47s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:01<00:00,  1.56s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:02<00:00,  1.48s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:02<00:00,  1.44s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:02<00:00,  1.44s/it]
# ...
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:06<00:00,  3.14s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:06<00:00,  3.07s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2861.06it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:03<00:00,  3.03s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:03<00:00,  3.06s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:05<00:00,  2.92s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:05<00:00,  2.85s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:05<00:00,  2.93s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:05<00:00,  2.96s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2619.88it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:03<00:00,  3.27s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:03<00:00,  3.23s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:05<00:00,  2.92s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:05<00:00,  3.00s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:05<00:00,  2.96s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:05<00:00,  2.95s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 3363.55it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:03<00:00,  3.13s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:03<00:00,  3.12s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:05<00:00,  2.91s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:05<00:00,  2.84s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:05<00:00,  2.95s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:05<00:00,  2.90s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 3161.68it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:03<00:00,  3.22s/it]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:03<00:00,  3.39s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:05<00:00,  2.97s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:05<00:00,  2.94s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:05<00:00,  2.96s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:05<00:00,  2.91s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 3438.51it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:03<00:00,  3.11s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:03<00:00,  3.01s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:05<00:00,  2.85s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:05<00:00,  2.90s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:05<00:00,  2.83s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:05<00:00,  2.96s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 1542.88it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:03<00:00,  3.08s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:03<00:00,  3.22s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:05<00:00,  2.94s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:05<00:00,  2.91s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:05<00:00,  2.90s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:05<00:00,  2.92s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 3656.57it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:03<00:00,  3.21s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:03<00:00,  3.20s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:05<00:00,  2.87s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:05<00:00,  2.87s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:05<00:00,  2.93s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:06<00:00,  3.03s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 3880.56it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:03<00:00,  3.08s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:03<00:00,  3.21s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:05<00:00,  2.91s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:05<00:00,  2.98s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:05<00:00,  2.94s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:05<00:00,  2.95s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 4080.11it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:02<00:00,  2.97s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:03<00:00,  3.06s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:05<00:00,  2.84s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:05<00:00,  2.88s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:05<00:00,  2.84s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:05<00:00,  2.97s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 4446.77it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:02<00:00,  2.95s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:02<00:00,  2.93s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:05<00:00,  2.79s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:05<00:00,  2.85s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:05<00:00,  2.87s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:05<00:00,  2.83s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 1853.48it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:03<00:00,  3.75s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:03<00:00,  3.62s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:06<00:00,  3.36s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:06<00:00,  3.32s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:06<00:00,  3.49s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:06<00:00,  3.38s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 1875.18it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:03<00:00,  3.67s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:03<00:00,  3.54s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:06<00:00,  3.39s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:06<00:00,  3.33s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:06<00:00,  3.27s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:06<00:00,  3.35s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 1980.69it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:03<00:00,  3.70s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:03<00:00,  3.52s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:06<00:00,  3.37s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:06<00:00,  3.30s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:06<00:00,  3.24s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:06<00:00,  3.40s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 1854.12it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:03<00:00,  3.57s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:03<00:00,  3.70s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:06<00:00,  3.37s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:06<00:00,  3.37s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:06<00:00,  3.26s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:06<00:00,  3.43s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2254.44it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:03<00:00,  3.41s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:03<00:00,  3.48s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:06<00:00,  3.39s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:06<00:00,  3.35s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:06<00:00,  3.31s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:06<00:00,  3.26s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2166.07it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:03<00:00,  3.65s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:03<00:00,  3.52s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:06<00:00,  3.33s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:06<00:00,  3.32s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:06<00:00,  3.45s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:06<00:00,  3.36s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2323.63it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:03<00:00,  3.47s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:03<00:00,  3.62s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:06<00:00,  3.20s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:06<00:00,  3.25s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:06<00:00,  3.31s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:06<00:00,  3.25s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2564.83it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:03<00:00,  3.33s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:03<00:00,  3.37s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:06<00:00,  3.13s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:06<00:00,  3.38s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:06<00:00,  3.30s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:06<00:00,  3.33s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2849.73it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:03<00:00,  3.50s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:03<00:00,  3.53s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:06<00:00,  3.16s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:06<00:00,  3.26s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:06<00:00,  3.20s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:06<00:00,  3.31s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2640.46it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:03<00:00,  3.46s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:03<00:00,  3.57s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:06<00:00,  3.31s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:06<00:00,  3.24s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:06<00:00,  3.22s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:06<00:00,  3.28s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2934.52it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:03<00:00,  3.29s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:03<00:00,  3.38s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:06<00:00,  3.17s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:06<00:00,  3.28s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:06<00:00,  3.22s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:06<00:00,  3.22s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 2859.45it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:03<00:00,  3.46s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:03<00:00,  3.43s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:06<00:00,  3.16s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:06<00:00,  3.14s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:06<00:00,  3.15s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:06<00:00,  3.21s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 3390.16it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:03<00:00,  3.31s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:03<00:00,  3.48s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:06<00:00,  3.21s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:06<00:00,  3.21s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:06<00:00,  3.24s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:06<00:00,  3.21s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 3083.63it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:03<00:00,  3.35s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:03<00:00,  3.57s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:06<00:00,  3.16s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:06<00:00,  3.31s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:06<00:00,  3.19s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:06<00:00,  3.30s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 3443.91it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:03<00:00,  3.36s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:03<00:00,  3.52s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:06<00:00,  3.17s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:06<00:00,  3.12s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:06<00:00,  3.21s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:06<00:00,  3.22s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 3398.61it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:03<00:00,  3.39s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:03<00:00,  3.43s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:06<00:00,  3.18s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:06<00:00,  3.10s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:06<00:00,  3.14s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:06<00:00,  3.26s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 1557.02it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:03<00:00,  3.37s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:03<00:00,  3.49s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:06<00:00,  3.19s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:06<00:00,  3.22s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:06<00:00,  3.28s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:06<00:00,  3.16s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 4536.88it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:03<00:00,  3.39s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:03<00:00,  3.28s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:06<00:00,  3.09s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:06<00:00,  3.14s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:06<00:00,  3.23s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:06<00:00,  3.13s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 4385.71it/s]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:03<00:00,  3.44s/it]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:03<00:00,  3.36s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:06<00:00,  3.11s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:06<00:00,  3.11s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:06<00:00,  3.14s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:06<00:00,  3.31s/it]
# Computing transition probabilities: 100%|██████████| 1000/1000 [00:00<00:00, 3968.99it/s]
# Generating walks (CPU: 6): 100%|██████████| 1/1 [00:03<00:00,  3.36s/it]
# Generating walks (CPU: 5): 100%|██████████| 1/1 [00:03<00:00,  3.51s/it]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:06<00:00,  3.15s/it]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:06<00:00,  3.33s/it]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:06<00:00,  3.29s/it]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:06<00:00,  3.24s/it]

# %% [markdown]
# ## Model training and evaluation

# %%
models_modelperfs_by_WL = dict()  # walk_length -> (models, model_performances)

# %%
for walk_length, (features, labels) in features_labels_by_WL.items():
    models = dict()  # theta -> [trained logistic regression]
    model_performances = dict()  # theta -> [performances]
    for theta in ExperimentParams.THETAS.value:
        # & Train model
        # Retrieve training features and labels
        X = features[theta][0]
        Y = labels[theta][0]

        # Train model
        model = train_fit_logreg(X, Y, LOGREG)

        # Save to models mapping
        models[theta] = model

        # & Test model
        # Retrieve testing features and labels labels
        X = features[theta][1]
        Y = labels[theta][1]

        # Apply model to test data
        model = models[theta]
        accuracy = get_model_accuracy(model, X, Y)
        auroc = get_model_auroc(model, X, Y)
        aupr = get_model_aupr(model, X, Y)
        performances = {
            "accuracy": accuracy,
            "auroc": auroc,
            "aupr": aupr,
        }

        # Save to models mapping
        model_performances[theta] = performances

    # Group by walk_length
    models_modelperfs_by_WL[walk_length] = (models, model_performances)

# %%
with open("logreg_by_walk-length.pkl", "wb") as _fh:
    pickle.dump(models_modelperfs_by_WL, _fh, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ---

# %% [markdown]
# # Analysis

# %%
with open("logreg_by_walk-length.pkl", "rb") as _fh:
    models_modelperfs_by_WL = pickle.load(_fh)
with open("../../data/output/raw/dc.pkl", "rb") as _fh:
    results_DC = pickle.load(_fh)[('DC', 1, 2)]

# %%
# Instantiate figure, subset relevant data
fig = plt.figure()

# Plotting data
X = sorted(ExperimentParams.THETAS.value)
idx = 0
idx2 = 0
for wl, (models, perfs) in models_modelperfs_by_WL.items():
    if idx % 2 == 0:
        Y = [perf["auroc"] for perf in perfs.values()]
        plt.plot(
            X, Y,
            label=f"{wl:.0f}",
            color=colors_[idx2],#viridis_(idx/(len(models_modelperfs_by_WL)-1)),
            marker="o"
        )
        idx2 += 1
    idx += 1
plt.plot(
    results_DC[0], results_DC[-1],
    label="\"DC\"-classifier",
    color="orange",
    marker="s",
    linestyle="--"
)

plt.hlines(0.5, 0, 1, linestyles=":", color="gray", alpha=0.5)

# Axes configuration
ax = fig.axes[0]

plt.xticks(np.linspace(0, 1, 11))
ax.xaxis.set_minor_locator(AutoMinorLocator(2))

plt.xlabel("$\\theta$")
plt.ylabel("ROC-AUC")

# Figure-level attributes
plt.legend(title="Walk Length") #, loc="lower right", bbox_to_anchor=(0.95, 0.25))
plt.title("Examining walk_length effect with Embeddings")

# Save plot
plt.savefig(f"{_FIGS}/line_auroc-pfi_hue-walklength_EMBex36.png")

# %%
# # Instantiate figure, subset relevant data
# fig = plt.figure()

# # Plotting data
# # plt.plot(
# #     results_FR_nodeg[0], results_FR_nodeg[-1],
# #     label="LogReg-FR-nodeg-classifier",
# #     color="red",
# #     marker="^",
# #     linestyle="-."
# # )
# plt.plot(
#     results_FR[0], results_FR[-1],
#     label="LogReg-FR-classifier",
#     color="orange",
#     marker="v",
#     linestyle="-."
# )
# plt.plot(
#     results_DC[0][1:], results_DC[-1][1:],
#     label="\"DC\"-classifier",
#     color="blue",
#     marker="o",
#     linestyle="--"
# )

# # plt.hlines(0.5, 0.05, 0.95, linestyles=":", color="gray", alpha=0.5)

# # Axes configuration
# ax = fig.axes[0]

# plt.xticks(np.linspace(0.1, 0.9, 9))
# ax.xaxis.set_minor_locator(AutoMinorLocator(2))

# plt.xlabel("$\\theta$")
# plt.ylabel("ROC-AUC")

# # Figure-level attributes
# plt.legend(title="Reconstruction", loc="lower right")
# plt.title("Examining size effect with Embeddings")

# # plt.fill_between(results_DC[0][1:7], results_DC[-1][1:7], results_FR[-1][:6], color="gray", alpha=0.15)
# # plt.fill_between(results_DC[0][-4:], results_DC[-1][-4:], results_FR[-1][-4:], color="red", alpha=0.1)

# # Save plot
# # plt.savefig(f"{_FIGS}/line_auroc-pfi_hue-method_EMBex35.png")

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Appendix

# %% [markdown]
# ## Referenced figures

# %% [markdown]
# <figure>
#     <center>
#     <img src="../../results/plots/line_auroc-theta_hue-features_gamma-2.1_compare-DC_EMB_ex33v2.1_DK_20230417.png" alt="ex33v2.1_comparison-fig" class="bg-primary" style="width:50%">
#     <figcaption><a id='ref-fig-1'>Reference Figure (1)</a>: EMB_ex33v2.1 results compared with prior results. </figcaption>
#     </center>
# </figure>

# %% [markdown]
# <figure>
#     <center>
#     <img src="../../results/plots/line_auroc-pfi_hue-size_style-method_EMBex34.png" alt="ex34_annotated-fig" class="bg-primary" style="width:50%">
#     <figcaption><a id='ref-fig-1'>Reference Figure (2)</a>: EMB_ex34 results show casing effect of network size on reconstruction. </figcaption>
#     </center>
# </figure>

# %% [markdown]
# <!-- ![Extra in case HTML does not render in pandoc export]("../../results/plots/line_auroc-theta_hue-features_gamma-2.1_compare-DC_EMB_ex33v2.1_DK_20230417.png") -->
