# %% [markdown]
# # Set-up

# %% [markdown]
# ## Imports

# %%
# --- Standard library ---
from datetime import datetime

# --- Data handling and visualization ---
import pandas as pd  # Dataframe tools
from tabulate import tabulate  # Pretty printing for dataframes

import seaborn as sns  # Easier plotting tools
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Globals

# %%
today = datetime.today().strftime("%Y%m%d")

# --- Visualization ---
rc_dict = {
  "savefig.dpi": 900,  # Saved figure dots-per-inch. 600 is "HD"
  "savefig.facecolor": "white",  # This, combined with transparent setting, keeps saved figs from looking like trash on dark backgrounds 
  "savefig.transparent": False,
  "figure.figsize": (14, 10),  # Default (width, height) of figure
}
plt.rcParams.update(rc_dict)

# %% [markdown]
# # Data preprocessing

# %%
# --- Synthetic ---
## Load dataframes
df_S_ex12 = pd.read_parquet("../../results/dataframes/dataframe_EMB_ex11-Sv1.0_DK_20221111.parquet")
df_S_ex10 = pd.concat([
    pd.read_parquet("../../results/dataframes/dataframe_EMB_ex10-Sv1.0-inverse_DK_20221010.parquet"),  # gamma, inverse
    pd.read_parquet("../../results/dataframes/dataframe_EMB_ex10-Sv1.0-negexp_DK_20221010.parquet"),  # gamma, negexp
    pd.read_parquet("../../results/dataframes/dataframe_EMB_ex10-Sv1.0-mu-inverse_DK_20221010.parquet"),  # mu, inverse
    pd.read_parquet("../../results/dataframes/dataframe_EMB_ex10-Sv1.0-mu-negexp_DK_20221010.parquet"),  # mu, negexp
])

## Label new and old results
df_S_ex12["Convex"] = [True]*len(df_S_ex12)
df_S_ex10["Convex"] = [False]*len(df_S_ex10)

## Concatenate
df_S = pd.concat([df_S_ex12, df_S_ex10])

## Fix indexing
df_S.index = range(len(df_S))

# %%
# # --- Real ---
# df_R_ex11 = pd.read_parquet("../../results/dataframes/dataframe_EMB_ex11-Rv1.0_DK_20221115.parquet")
# df_R_ex09 = pd.read_parquet("../../results/dataframes/dataframe_EMB_ex09-Rv1.1_DK_20221012.parquet")
# df_R_ex09_ext = pd.read_parquet("../../results/dataframes/dataframe_EMB_ex09-Rv1.2_DK_20221115.parquet")
# df_R_ex09_small_layers = pd.read_parquet("../../results/dataframes/dataframe_EMB_ex09-Rv1.2_DK_20221116.parquet")
# df_R_ex09 = pd.concat([df_R_ex09, df_R_ex09_ext, df_R_ex09_small_layers])

# ## Label new and old results
# df_R_ex11["Convex"] = [True]*len(df_R_ex11)
# df_R_ex09["Convex"] = [False]*len(df_R_ex09)

# ## Concatenate
# df_R = pd.concat([df_R_ex11, df_R_ex09])

# ## Fix indexing
# df_R.index = range(len(df_R))

# %% [markdown]
# # Figures

# %% [markdown]
# ## ex12-S

# %%
plt.figure()
sns.relplot(
    data=df_S, kind="line",
    x="pfi", y="AUROC",
    hue="Convex",
    style="Convex", markers=True
)

plt.title("Performance on LFRs")
plt.ylabel("AUROC")
plt.xlabel("PFI")

plt.tight_layout()
plt.savefig(f"../../results/plots/line_auroc-pfi_EMB_ex12-S_DK_{today}.png")

# %% [markdown]
# ## ex12-R

# %%
plt.figure()
sns.relplot(
    data=df_R, kind="line",
    x="pfi", y="AUROC",
    hue="Convex",
    style="Convex", markers=True,
    col="system", col_wrap=2
)

plt.ylabel("AUROC")
plt.xlabel("PFI")

plt.tight_layout()
plt.savefig(f"../../results/plots/line_auroc-pfi_EMB_ex12-R_DK_{today}.png")

# %%
system_ = "arxiv"
plt.figure()
sns.relplot(
    data=df_R.query("system == @system_"), kind="line",
    x="pfi", y="AUROC",
    hue="Convex",
    style="Convex", markers=True,
    row="alpha", col="beta"
)

plt.suptitle(f"{system_}")
plt.ylabel("AUROC")
plt.xlabel("PFI")

plt.tight_layout()
plt.savefig(f"../../results/plots/line_auroc-pfi_system={system_}_EMB_ex12-R_DK_{today}.png")

# %%
system_ = "drosophila"
plt.figure()
sns.relplot(
    data=df_R.query("system == @system_"), kind="line",
    x="pfi", y="AUROC",
    hue="Convex",
    style="Convex", markers=True,
    row="alpha", col="beta"
)

plt.suptitle(f"{system_}")
plt.ylabel("AUROC")
plt.xlabel("PFI")

plt.tight_layout()
plt.savefig(f"../../results/plots/line_auroc-pfi_system={system_}_EMB_ex12-R_DK_{today}.png")

# %%
system_ = "celegans"
plt.figure()
sns.relplot(
    data=df_R.query("system == @system_"), kind="line",
    x="pfi", y="AUROC",
    hue="Convex",
    style="Convex", markers=True,
    row="alpha", col="beta"
)

plt.suptitle(f"{system_}")
plt.ylabel("AUROC")
plt.xlabel("PFI")

plt.tight_layout()
plt.savefig(f"../../results/plots/line_auroc-pfi_system={system_}_EMB_ex12-R_DK_{today}.png")

# %%
system_ = "london"
plt.figure()
sns.relplot(
    data=df_R.query("system == @system_"), kind="line",
    x="pfi", y="AUROC",
    hue="Convex",
    style="Convex", markers=True,
    row="alpha", col="beta"
)

plt.suptitle(f"{system_}")
plt.ylabel("AUROC")
plt.xlabel("PFI")

plt.tight_layout()
plt.savefig(f"../../results/plots/line_auroc-pfi_system={system_}_EMB_ex12-R_DK_{today}.png")
